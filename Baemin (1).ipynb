# %%
import requests
import pandas as pd
import time

# %%
#keys
API_key = 'AIzaSyDNfpCk_k4Lxlx5-sw0Ol9fEnZuf8bzATQ'
Channel_ID = 'UCv6k0KftaSy_hqhkW7K2EqQ'

#create the url link
url = 'https://www.googleapis.com/youtube/v3/search?key=AIzaSyDNfpCk_k4Lxlx5-sw0Ol9fEnZuf8bzATQ&channelId=UCv6k0KftaSy_hqhkW7K2EqQ&part=snippet,id&maxResults=50&order=date'

response = requests.get(url).json()

# %%
#Create a dataframe for use later after we've got the data:
df = pd.DataFrame(columns = ['video_id','video_title','upload_date','view_count','like_count','comment_count'])

# %%
#Using For-loop to get the data we need:
for video in response['items']:
    if video['id']['kind'] == 'youtube#video':
        video_id =  video['id']['videoId']
        published_date = video['snippet']['publishedAt']
        published_date = str(published_date).split('T')[0]
        video_title = video['snippet']['title']
        
        
        #collect statistics including likes, comments, views:
        url_statistics = "https://www.googleapis.com/youtube/v3/videos?key=AIzaSyDNfpCk_k4Lxlx5-sw0Ol9fEnZuf8bzATQ&part=statistics&id="+video_id
        second_api_call = requests.get(url_statistics).json()
        view_count = second_api_call['items'][0]['statistics']['viewCount']
        like_count = second_api_call['items'][0]['statistics']['likeCount']
        comment_count = second_api_call['items'][0]['statistics']['commentCount']
        
       #Save data into the previously created dataframe:
        df = df.append({'video_id':video_id,'video_title':video_title,'upload_date':published_date,
                        'view_count':view_count, 'like_count':like_count, 'comment_count':comment_count
                       },ignore_index=True)

# %%
df
# Out:
#        video_id                                        video_title  \
# 0   22RLWpzclOY                   TỚI BỮA RỒI, BẠN ĐÃ ĂN CƠM CHƯA?
# 1   tm-gkP-0xvY  &quot;BẠN ƠI, ĂN CƠM CHƯA? TỚI BỮA ĐẶT BAEMIN ...
# 2   qurmgL0Oyfk                    DEAL CHỒNG DEAL, TẾT SIÊU LỚN 🎊
# 3   OmGR7K3iRqY              TẾT BẬN, CHƯA ĂN CƠM? ĐẶT BAEMIN NGAY
# 4   gnPjDaSD8RU                    🎉 BAEMIN SALE TRỘI MÙA LỄ HỘI 🎉
# 5   WIJ7W6DKmSk      BAEMIN BLACK FRIDAY 2021 - Siêu Sale Toàn App
# 6   t1nUjHQZLtY          BEST BAE - KHÁCH HÀNG THÂN THIẾT BAEMIN 💜
# 7   -u9ypX0yAH8       BAEMIN SALE LỚN HALLOWEEN 🎃  15/10 - 31/10 🎃
# 8   0dlGRWT8s2M   NUÔI MA MẬP - CÙNG BAEMIN SĂN SALE LỚN HALLOWEEN
# 9   xHs5Cgn0-0k                                  SỢ MA HAY SỢ MẬP?
# 10  tpSPYWjR_-g  Ánh Trăng Đói Hộ Lòng Tôi (Phiên Bản Phong Vị ...
# 11  r2KkVjhr--Q  Ánh Trăng Đói Hộ Lòng Tôi (Phiên Bản Món Ngon ...
# 12  D3RmSnrwmbU             BAEMIN Sinh Nhật Diệu Kỳ - Rider video
# ...
